# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
pok=pd.read_csv('Pokemon.csv')    #pok is  a dataframe

# %%
pok.head()
# Out:
#    number                 name  type1   type2  total  hp  attack  defense  \
# 0       1            Bulbasaur  Grass  Poison    318  45      49       49
# 1       2              Ivysaur  Grass  Poison    405  60      62       63
# 2       3             Venusaur  Grass  Poison    525  80      82       83
# 3       3        Mega Venusaur  Grass  Poison    625  80     100      123
# 4       3  Gigantamax Venusaur  Grass  Poison    525  80      82       83
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0         65          65     45           1      False
# 1         80          80     60           1      False
# 2        100         100     80           1      False
# 3        122         120     80           1      False
# 4        100         100     80           1      False

# %%
pok.rename(columns={'type1':'Primary_Type','type2':'Secondary_Type'},inplace=True)

# %%
pok.head()
# Out:
#    number                 name Primary_Type Secondary_Type  total  hp  attack  \
# 0       1            Bulbasaur        Grass         Poison    318  45      49
# 1       2              Ivysaur        Grass         Poison    405  60      62
# 2       3             Venusaur        Grass         Poison    525  80      82
# 3       3        Mega Venusaur        Grass         Poison    625  80     100
# 4       3  Gigantamax Venusaur        Grass         Poison    525  80      82
#
#    defense  sp_attack  sp_defense  speed  generation  legendary
# 0       49         65          65     45           1      False
# 1       63         80          80     60           1      False
# 2       83        100         100     80           1      False
# 3      123        122         120     80           1      False
# 4       83        100         100     80           1      False

# %%
pok['Primary_Type']=="Grass"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1067    False
# 1068    False
# 1069    False
# 1070    False
# 1071    False
# Name: Primary_Type, Length: 1072, dtype: bool

# %%
pok[pok['Primary_Type']=="Grass"]   #here we get rows that have primary type as grass
# Out:
#      number                 name Primary_Type Secondary_Type  total   hp  \
# 0         1            Bulbasaur        Grass         Poison    318   45
# 1         2              Ivysaur        Grass         Poison    405   60
# 2         3             Venusaur        Grass         Poison    525   80
# 3         3        Mega Venusaur        Grass         Poison    625   80
# 4         3  Gigantamax Venusaur        Grass         Poison    525   80
# ..      ...                  ...          ...            ...    ...  ...
# 990     840               Applin        Grass         Dragon    260   40
# 991     841              Flapple        Grass         Dragon    485   70
# 992     841   Gigantamax Flapple        Grass         Dragon    485   70
# 993     842             Appletun        Grass         Dragon    485  110
# 994     842  Gigantamax Appletun        Grass         Dragon    485  110
#
#      attack  defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
grass_pok=pok[pok['Primary_Type']=="Grass"]

# %%
grass_pok.head()
# Out:
#    number                 name Primary_Type Secondary_Type  total  hp  attack  \
# 0       1            Bulbasaur        Grass         Poison    318  45      49
# 1       2              Ivysaur        Grass         Poison    405  60      62
# 2       3             Venusaur        Grass         Poison    525  80      82
# 3       3        Mega Venusaur        Grass         Poison    625  80     100
# 4       3  Gigantamax Venusaur        Grass         Poison    525  80      82
#
#    defense  sp_attack  sp_defense  speed  generation  legendary
# 0       49         65          65     45           1      False
# 1       63         80          80     60           1      False
# 2       83        100         100     80           1      False
# 3      123        122         120     80           1      False
# 4       83        100         100     80           1      False

# %%
water_pok=pok[pok['Primary_Type']=="Water"]

# %%
water_pok.head()
# Out:
#     number            name Primary_Type Secondary_Type  total  hp  attack  \
# 11       7        Squirtle        Water            NaN    314  44      48
# 12       8       Wartortle        Water            NaN    405  59      63
# 13       9       Blastoise        Water            NaN    530  79      83
# 14       9  Mega Blastoise        Water            NaN    630  79     103
# 77      54         Psyduck        Water            NaN    320  50      52
#
#     defense  sp_attack  sp_defense  speed  generation  legendary
# 11       65         50          64     43           1      False
# 12       80         65          80     58           1      False
# 13      100         85         105     78           1      False
# 14      120        135         115     78           1      False
# 77       48         65          50     55           1      False

# %%
fire_pok=pok[pok['Primary_Type']=="Fire"]

# %%
fire_pok.head()
# Out:
#    number              name Primary_Type Secondary_Type  total  hp  attack  \
# 5       4        Charmander         Fire            NaN    309  39      52
# 6       5        Charmeleon         Fire            NaN    405  58      64
# 7       6         Charizard         Fire         Flying    534  78      84
# 8       6  Mega Charizard X         Fire         Dragon    634  78     130
# 9       6  Mega Charizard Y         Fire         Flying    634  78     104
#
#    defense  sp_attack  sp_defense  speed  generation  legendary
# 5       43         60          50     65           1      False
# 6       58         80          65     80           1      False
# 7       78        109          85    100           1      False
# 8      111        130          85    100           1      False
# 9       78        159         115    100           1      False

# %%
pok.shape
# Out:
# (1072, 13)

# %%
grass_pok.shape
# Out:
# (94, 13)

# %%
fire_pok.shape
# Out:
# (67, 13)

# %%
water_pok.shape
# Out:
# (136, 13)

# %%
(136+67+94)/1072
# Out:
# 0.27705223880597013

# %%
grass_pok.head()
# Out:
#    number                 name Primary_Type Secondary_Type  total  hp  attack  \
# 0       1            Bulbasaur        Grass         Poison    318  45      49
# 1       2              Ivysaur        Grass         Poison    405  60      62
# 2       3             Venusaur        Grass         Poison    525  80      82
# 3       3        Mega Venusaur        Grass         Poison    625  80     100
# 4       3  Gigantamax Venusaur        Grass         Poison    525  80      82
#
#    defense  sp_attack  sp_defense  speed  generation  legendary
# 0       49         65          65     45           1      False
# 1       63         80          80     60           1      False
# 2       83        100         100     80           1      False
# 3      123        122         120     80           1      False
# 4       83        100         100     80           1      False

# %%
sns.histplot(grass_pok['speed']) #histogram of speed of grass type pokemons
plt.show()

# %%
sns.histplot(grass_pok['sp_attack'])
# Out:
# <Axes: xlabel='sp_attack', ylabel='Count'>

# %%
sns.histplot(grass_pok['sp_defense'])
# Out:
# <Axes: xlabel='sp_defense', ylabel='Count'>

# %%
grass_pok.describe()
# Out:
#            number       total          hp      attack     defense   sp_attack  \
# count   94.000000   94.000000   94.000000   94.000000   94.000000   94.000000
# mean   442.393617  421.436170   67.797872   76.170213   72.117021   75.574468
# std    262.489005  108.889957   20.090430   29.430303   23.973039   27.001589
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    207.000000  318.000000   50.500000   55.000000   55.000000   55.000000
# 50%    460.000000  442.500000   69.500000   75.000000   70.000000   74.500000
# 75%    667.000000  513.750000   78.000000  100.000000   85.000000   97.750000
# max    842.000000  630.000000  123.000000  181.000000  131.000000  145.000000
#
#        sp_defense       speed  generation
# count   94.000000   94.000000   94.000000
# mean    69.734043   60.042553    4.329787
# std     21.591603   27.930757    2.264206
# min     30.000000   10.000000    1.000000
# 25%     55.000000   38.500000    3.000000
# ...

# %%
water_pok.head()
# Out:
#     number            name Primary_Type Secondary_Type  total  hp  attack  \
# 11       7        Squirtle        Water            NaN    314  44      48
# 12       8       Wartortle        Water            NaN    405  59      63
# 13       9       Blastoise        Water            NaN    530  79      83
# 14       9  Mega Blastoise        Water            NaN    630  79     103
# 77      54         Psyduck        Water            NaN    320  50      52
#
#     defense  sp_attack  sp_defense  speed  generation  legendary
# 11       65         50          64     43           1      False
# 12       80         65          80     58           1      False
# 13      100         85         105     78           1      False
# 14      120        135         115     78           1      False
# 77       48         65          50     55           1      False

# %%
sns.histplot(water_pok['sp_attack'])
# Out:
# <Axes: xlabel='sp_attack', ylabel='Count'>

# %%
sns.histplot(water_pok['sp_defense'])
# Out:
# <Axes: xlabel='sp_defense', ylabel='Count'>

# %%
water_pok.describe()
# Out:
#            number       total          hp      attack     defense   sp_attack  \
# count  136.000000  136.000000  136.000000  136.000000  136.000000  136.000000
# mean   379.279412  433.294118   71.132353   75.750000   73.477941   74.992647
# std    251.405345  113.817470   26.450459   29.235379   27.897422   30.315989
# min      7.000000  175.000000   20.000000   10.000000   20.000000   10.000000
# 25%    158.750000  328.750000   50.000000   55.000000   54.750000   52.250000
# 50%    341.500000  460.000000   70.000000   73.500000   70.000000   70.000000
# 75%    568.750000  509.250000   90.000000   92.750000   90.000000   92.500000
# max    883.000000  770.000000  170.000000  155.000000  180.000000  180.000000
#
#        sp_defense       speed  generation
# count  136.000000  136.000000  136.000000
# mean    71.397059   66.544118    3.573529
# std     29.204079   25.119527    2.243121
# min     20.000000    5.000000    1.000000
# 25%     50.000000   50.000000    2.000000
# ...

# %%
grass_pok.describe()
# Out:
#            number       total          hp      attack     defense   sp_attack  \
# count   94.000000   94.000000   94.000000   94.000000   94.000000   94.000000
# mean   442.393617  421.436170   67.797872   76.170213   72.117021   75.574468
# std    262.489005  108.889957   20.090430   29.430303   23.973039   27.001589
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    207.000000  318.000000   50.500000   55.000000   55.000000   55.000000
# 50%    460.000000  442.500000   69.500000   75.000000   70.000000   74.500000
# 75%    667.000000  513.750000   78.000000  100.000000   85.000000   97.750000
# max    842.000000  630.000000  123.000000  181.000000  131.000000  145.000000
#
#        sp_defense       speed  generation
# count   94.000000   94.000000   94.000000
# mean    69.734043   60.042553    4.329787
# std     21.591603   27.930757    2.264206
# min     30.000000   10.000000    1.000000
# 25%     55.000000   38.500000    3.000000
# ...

# %%
sns.histplot(fire_pok['speed'],color='red')
# Out:
# <Axes: xlabel='speed', ylabel='Count'>

# %%
sns.histplot(fire_pok['sp_attack'],color='red')
# Out:
# <Axes: xlabel='sp_attack', ylabel='Count'>

# %%
sns.histplot(fire_pok['sp_defense'],color='red')
# Out:
# <Axes: xlabel='sp_defense', ylabel='Count'>

# %%
fire_pok.describe()
# Out:
#            number       total          hp      attack     defense   sp_attack  \
# count   67.000000   67.000000   67.000000   67.000000   67.000000   67.000000
# mean   409.641791  458.582090   70.014925   86.507463   68.283582   86.582090
# std    279.557589  104.926403   19.021911   27.453748   24.061037   29.828372
# min      4.000000  250.000000   38.000000   30.000000   37.000000   15.000000
# 25%    155.500000  375.500000   58.000000   65.000000   51.000000   65.000000
# 50%    391.000000  484.000000   70.000000   85.000000   65.000000   81.000000
# 75%    662.500000  534.000000   80.000000  107.000000   78.000000  107.000000
# max    851.000000  680.000000  115.000000  160.000000  140.000000  159.000000
#
#        sp_defense       speed  generation
# count   67.000000   67.000000   67.000000
# mean    71.850746   75.343284    4.074627
# std     21.567550   25.450815    2.432815
# min     40.000000   20.000000    1.000000
# 25%     54.500000   60.000000    2.000000
# ...

# %%
water_pok.describe()
# Out:
#            number       total          hp      attack     defense   sp_attack  \
# count  136.000000  136.000000  136.000000  136.000000  136.000000  136.000000
# mean   379.279412  433.294118   71.132353   75.750000   73.477941   74.992647
# std    251.405345  113.817470   26.450459   29.235379   27.897422   30.315989
# min      7.000000  175.000000   20.000000   10.000000   20.000000   10.000000
# 25%    158.750000  328.750000   50.000000   55.000000   54.750000   52.250000
# 50%    341.500000  460.000000   70.000000   73.500000   70.000000   70.000000
# 75%    568.750000  509.250000   90.000000   92.750000   90.000000   92.500000
# max    883.000000  770.000000  170.000000  155.000000  180.000000  180.000000
#
#        sp_defense       speed  generation
# count  136.000000  136.000000  136.000000
# mean    71.397059   66.544118    3.573529
# std     29.204079   25.119527    2.243121
# min     20.000000    5.000000    1.000000
# 25%     50.000000   50.000000    2.000000
# ...

# %%
pok.head()
# Out:
#    number                 name Primary_Type Secondary_Type  total  hp  attack  \
# 0       1            Bulbasaur        Grass         Poison    318  45      49
# 1       2              Ivysaur        Grass         Poison    405  60      62
# 2       3             Venusaur        Grass         Poison    525  80      82
# 3       3        Mega Venusaur        Grass         Poison    625  80     100
# 4       3  Gigantamax Venusaur        Grass         Poison    525  80      82
#
#    defense  sp_attack  sp_defense  speed  generation  legendary
# 0       49         65          65     45           1      False
# 1       63         80          80     60           1      False
# 2       83        100         100     80           1      False
# 3      123        122         120     80           1      False
# 4       83        100         100     80           1      False

# %%
pok['legendary'].value_counts()
# Out:
# legendary
# False    954
# True     118
# Name: count, dtype: int64

# %% [markdown]
# above we can see it is inbalanced dataset.

# %%
954+118
# Out:
# 1072

# %%
118/1072
# Out:
# 0.11007462686567164

# %%
x = pok[['speed']]

# %%
y= pok[['legendary']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc =DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %%
from sklearn.metrics import  confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[288,   3],
#        [ 29,   2]], dtype=int64)

# %%
(282+5)/(282+4+31+5)  #left diagonal give us accurate
# Out:
# 0.8913043478260869

# %% [markdown]
# regression with desion tree

# %%
x=pok[['defense']]  #independent

# %%
y=pok[['attack']] #dependent

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(x_test)

# %%
y_test.head()
# Out:
#       attack
# 1006     115
# 290       90
# 912       60
# 983      115
# 505       69

# %%
y_pred[0:5]
# Out:
# array([ 78.58536585,  66.09756098, 105.51851852,  91.1875    ,
#        100.43478261])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 851.1622977776696
